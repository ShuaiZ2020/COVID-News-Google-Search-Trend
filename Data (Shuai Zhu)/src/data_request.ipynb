# %%
# !pip install pytrends

# %%
from pytrends.request import TrendReq

# %%
pytrends = TrendReq(hl='en-US', tz=360)
kw_list = ['covid news']
pytrends.build_payload(kw_list, cat=0, timeframe='today 5-y', geo='US-AZ', gprop='news')

# %%
data = pytrends.interest_over_time()
data
# Out:
#             covid news  isPartial
# date
# 2017-07-23           0      False
# 2017-07-30           0      False
# 2017-08-06           0      False
# 2017-08-13           0      False
# 2017-08-20           0      False
# ...                ...        ...
# 2022-06-19          18      False
# 2022-06-26           0      False
# 2022-07-03           0      False
# 2022-07-10          18      False
# 2022-07-17           0       True
#
# [261 rows x 2 columns]

# %%
data.iloc[-10:,:]
# Out:
#             covid news  isPartial
# date
# 2022-05-15           0      False
# 2022-05-22           0      False
# 2022-05-29           0      False
# 2022-06-05          39      False
# 2022-06-12          18      False
# 2022-06-19          18      False
# 2022-06-26           0      False
# 2022-07-03           0      False
# 2022-07-10          18      False
# 2022-07-17           0       True
